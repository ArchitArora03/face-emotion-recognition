# %%
import tensorflow as tf
import numpy as np

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img1=cv2.imread('happy.jpg')

# %%
plt.imshow(img1)

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

# %%
predictions=DeepFace.analyze(img1)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.92it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.03492384193011176,
#    'disgust': 8.904040631510003e-05,
#    'fear': 0.004830680624384955,
#    'happy': 98.52803936767813,
#    'sad': 0.004076653083000144,
#    'surprise': 0.6422552662941973,
#    'neutral': 0.7857797204422784},
#   'dominant_emotion': 'happy',
#   'region': {'x': 79, 'y': 34, 'w': 80, 'h': 80},
#   'age': 23,
#   'gender': {'Woman': 0.005346221223589964, 'Man': 99.99465942382812},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.11703406459668664,
#    'indian': 0.799176517079861,
#    'black': 0.017681553034688713,
#    'white': 53.8231464518992,
#    'middle eastern': 23.520970256386416,
#    'latino hispanic': 21.721988721012398},
#   'dominant_race': 'white'}]

# %%
prediction=predictions[0]

# %%
prediction
# Out:
# {'emotion': {'angry': 0.03492384193011176,
#   'disgust': 8.904040631510003e-05,
#   'fear': 0.004830680624384955,
#   'happy': 98.52803936767813,
#   'sad': 0.004076653083000144,
#   'surprise': 0.6422552662941973,
#   'neutral': 0.7857797204422784},
#  'dominant_emotion': 'happy',
#  'region': {'x': 79, 'y': 34, 'w': 80, 'h': 80},
#  'age': 23,
#  'gender': {'Woman': 0.005346221223589964, 'Man': 99.99465942382812},
#  'dominant_gender': 'Man',
#  'race': {'asian': 0.11703406459668664,
#   'indian': 0.799176517079861,
#   'black': 0.017681553034688713,
#   'white': 53.8231464518992,
#   'middle eastern': 23.520970256386416,
#   'latino hispanic': 21.721988721012398},
#  'dominant_race': 'white'}

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(img1,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
font= cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img1,
            prediction['dominant_emotion'],
            (0,50),
            font,1
            ,(0, 0, 255),2, cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
